# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('C:\\Users\\Erik\\git\\pluto\\PWR_Board_TestReportTemplate.xlsx', 'Report')

df
df2= pd.read_excel('C:\\Users\\Erik\\git\\pluto\\PWR_Board_TestReportTemplate.xlsx', 'Quantities')
df2
# Out:
#     TEST #                                 TEST DESCRIPTION              NAME  \
# 0        1                                 PSUA UVLO Rising    PsuaUvloRising
# 1        2                                PSUA UVLO Falling   PsuaUvloFalling
# 2        3                                 PSUA OVLO Rising    PsuaOvloRising
# 3        4                                PSUA OVLO Falling   PsuaOvloFalling
# 4        5                                 PSUB UVLO Rising    PsubUvloRising
# 5        6                                PSUB UVLO Falling   PsubUvloFalling
# 6        7                                 PSUB OVLO Rising    PsubOvloRising
# 7        8                                PSUB OVLO Falling   PsubOvloFalling
# 8        9                                           24VOUT            24Vout
# 9       10                               HV CAP CHARGE TIME        ChargeTime
# 10      11                              HV CAP CHARGE LEVEL       ChargeLevel
# 11      12                                   HV CAP STORAGE      ChargeAmount
# 12      13                                     D7H, D8H FWB       inputDiode1
# 13      14                                     D6H, D8H FWB       inputDiode2
# 14      15                                     D5H, D9H FWB       inputDiode3
# 15      16                                    D5H, D10H FWB       inputDiode4
# 16      17                                     D2H, D3H FWB       inputDiode5
# 17      18                                     D1H, D4H FWB       inputDiode6
# 18      19                                 HVBUCK BOOTSTRAP   HvBuckBootstrap
# 19      20                                        AUXEN LOW          AuxenLow
# 20      21                                       AUXEN HIGH         AuxenHigh
# 21      22                                      HVBUCK UVLO        HvBuckUVLO
# 22      23                                    HVBUCK OUTPUT   HvBuckOutput On
# 23      24                                HVBUCK EFFICIENCY  HvBuckEfficiency
# 24      25                                              NaN     HvBuckCurrent
# 25      26                                       SPM ACTIVE         SpmActive
# 26      27                                     SPM INACTIVE       SpmInactive
# 27      28                                  PSUFAULT ACTIVE    PsuFaultActive
# 28      29                                PSUFAULT INACTIVE  PsuFaultInactive
# 29      30  Fault out to motherboard when it should be high      FltOutActive
# 30      31   Fault out to motherboard when it should be low    FltOutInactive
#
#       MIN     MAX  NOMINAL  MEASURED UNITS  PASS/FAIL  TIMESTAMP
# 0    20.0    20.4    20.18       NaN     V        NaN        NaN
# 1    20.0    20.4    20.18       NaN     V        NaN        NaN
# 2    30.0    30.4    30.20       NaN     V        NaN        NaN
# 3    30.0    30.4    30.20       NaN     V        NaN        NaN
# 4    20.0    20.4    20.18       NaN     V        NaN        NaN
# 5    20.0    20.4    20.18       NaN     V        NaN        NaN
# 6    30.0    30.4    30.20       NaN     V        NaN        NaN
# 7    30.0    30.4    30.20       NaN     V        NaN        NaN
# 8    23.7    24.3    24.00       NaN     V        NaN        NaN
# 9    40.0   200.0   180.00       NaN   SEC        NaN        NaN
# 10  310.0   320.0   315.00       NaN     V        NaN        NaN
# 11  950.0  1050.0  1000.00       NaN     J        NaN        NaN
# 12  835.0   845.0   840.00       NaN     V        NaN        NaN
# 13  835.0   845.0   840.00       NaN     V        NaN        NaN
# 14  835.0   845.0   840.00       NaN     V        NaN        NaN
# 15  835.0   845.0   840.00       NaN     V        NaN        NaN
# 16  835.0   845.0   840.00       NaN     V        NaN        NaN
# 17  835.0   845.0   840.00       NaN     V        NaN        NaN
# 18   23.9    24.1    24.00       NaN     V        NaN        NaN
# 19    0.0     1.0     0.00       NaN     V        NaN        NaN
# 20   15.8    16.2    16.00       NaN     V        NaN        NaN
# 21  280.0   300.0   290.00       NaN     V        NaN        NaN
# 22  238.0   242.0   240.00       NaN     V        NaN        NaN
# 23    0.8     1.0     0.90       NaN     %        NaN        NaN
# 24    NaN     NaN      NaN       NaN     A        NaN        NaN
# 25    0.0     0.2     0.00       NaN     V        NaN        NaN
# 26    4.8     5.1     5.00       NaN     V        NaN        NaN
# 27    0.0     0.2     0.00       NaN     V        NaN        NaN
# 28    4.8     5.1     5.00       NaN     V        NaN        NaN
# 29    0.0     0.2     0.00       NaN     V        NaN        NaN
# 30    4.8     5.1     5.00       NaN     V        NaN        NaN
#        Quantity  Channel   Min     Max  Nominal  Scale
# 0          PSUA      201   23.5   24.5     24.0   1.00
# 1          PSUB      202   23.5   24.5     24.0   1.00
# 2          PSUC      203   23.5   24.5     24.0   1.00
# 3        24Vout      204   23.5   24.5     24.0   1.00
# 4       FLT_OUT      205    0.0    5.0      0.0   1.00
# 5          TEMP      206    0.0    5.0      2.5   1.00
# 6           SPM      207    0.0    5.0      0.0   1.00
# 7       PSU_FLT      208    0.0    5.0      0.0   1.00
# 8         HVCAP      210  300.0  330.0    315.0   4.00
# 9          TP5B      211  230.0  250.0    240.0   4.00
# 10         TP1B      212  300.0  850.0    650.0   5.00
# 11         TP6B      213   15.0   17.0     16.0   1.00
# 12         TP2B      214   23.0   25.0     24.0   1.00
# 13  BuckCurrent      215    0.0    NaN      0.0   3.57

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                   index=[0, 1, 2, 3])
df1
'''

'''
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# '\n\n'

# %%
for row in df1.iterrows():
    print(type(row[1]))
    print(row[1])

# %%
#column_names = df1.columns.tolist()
for row in df1.iterrows():
    #this next part in constructor of each test class object
    ser = row[1] #(index, Series) comes from iterrows()
    column_names = ser.index.tolist()
    my_dict = {}
    for column_name in column_names:
        my_dict[column_name] = ser[column_name]
    print(my_dict) #each test classs object has a dictionary
# Out:
# {'A': 'A0', 'B': 'B0', 'C': 'C0', 'D': 'D0'}
# {'A': 'A1', 'B': 'B1', 'C': 'C1', 'D': 'D1'}
# {'A': 'A2', 'B': 'B2', 'C': 'C2', 'D': 'D2'}
# {'A': 'A3', 'B': 'B3', 'C': 'C3', 'D': 'D3'}

# %%
params = df1.columns.tolist()
params

# %%
a = {'A': 'A0', 'B': 'B0', 'C': 'C0', 'D': 'D0'}
b = {'A': 'A1', 'B': 'B1', 'C': 'C1', 'D': 'D1'}
c = {'A': 'A2', 'B': 'B2', 'C': 'C2', 'D': 'D2'}
d = {'A': 'A3', 'B': 'B3', 'C': 'C3', 'D': 'D3'}

# %%
seasons = ['Spring', 'Summer', 'Fall', 'Winter']
list(enumerate(seasons))
enum = enumerate(seasons)

# %%
df = pd.DataFrame(data=[a,b,c,d])
df['TestName'] = ['test1', 'test2','test3','test4']
df
enumerate(df['TestName'])

# %% [markdown]
# There are tests, which have margins, pass/fail status, timestamp, units.
# There are quantities, which are used to evaluate tests, and they have channel assignments.
# A quantity can know for what test numbers what the valid margins are, answersing queries such
# as .valid() or .invalid()
# Tests can use 0 or more quantities, to evaluate pass/fail status.
#
#
# Tests are ordered and numbered sequentially, so one can access them from a list of objects.
#
# Tests also use stimuli, such as input voltages.
# Test jig actions, such as relay configuration, may be encapsulated by a class also.
